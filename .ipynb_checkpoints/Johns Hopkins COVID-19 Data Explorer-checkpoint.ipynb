# %% [markdown]
# # COVID-19 Data Explorer
# Created by [Brandon Bellanti](mailto:brandonbellanti@gmail.com)
# <br>Updated Aug. 7, 2020
#
# ---
# # Introduction
#
# This notebook contains code for exploring and visualizing COVID-19 case and death data.
#
# ## Sections
# * [Fetch and format data](#Fetch-and-format-data)
# * [Filter data](#Filter-data)
# * [Explore data](#Explore-data)
# * [Visualize data](#Report-data)
#
# ## Source
#
# The data used in this notebook is sourced from Johns Hopkins University's GitHub repository: https://github.com/CSSEGISandData/COVID-19. The data includes both confirmed and probable cases/deaths.
#
# ## Field Descriptions
# * `FIPS` - US only. Federal Information Processing Standards code that uniquely identifies counties within the USA.
# * `Lat` and `Long_` - Dot locations on the dashboard. All points (except for Australia) shown on the map are based on geographic centroids, and are not representative of a specific address, building or any location at a spatial scale finer than a province/state. Australian dots are located at the centroid of the largest city in each state.
# * `UID` - Unique Identifier for each row entry.
# * `Combined_Key`
# * `iso2` and `iso3` - Officialy assigned country code identifiers.
# * `Country_Region` - Country, region or sovereignty name. The names of locations included on the Website correspond with the official designations used by the U.S. Department of State.
# * `code3` -
# * `Admin2` - county
# * `Province_State` - Province, state or dependency name.
#
# ## Working on
# * Plotting heatmaps for different counties
# * Fixing errors on counties with no cases
# * Slicing by timeframe: week, month, all
# * Subplots using `df.groupby()` function

# %% [markdown]
# [Return to top](#Introduction)
#
# ---
# # Fetch and format data

# %%
# load libraries
import pandas as pd, numpy as np, matplotlib.pyplot as plt,seaborn as sns,math,warnings
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings('ignore')

# urls for jhu datasets
cases_csv_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
deaths_csv_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'

# load dataframes from urls
cases_df = pd.read_csv(cases_csv_url)
deaths_df = pd.read_csv(deaths_csv_url)

# combine dfs with new column for report type
cases_df['Report_Type'] = 'cases'
deaths_df['Report_Type'] = 'deaths'
reports_df = cases_df.append(deaths_df,ignore_index=True)

# rename date columns (pad month and day values) for later filtering/sorting
date_cols = reports_df.filter(regex=r'\d{1,2}\/\d{1,2}\/\d{2}').columns.to_list()
date_formatter = lambda x: "{:0>2}/{:0>2}/{:0>2}".format(*(x.split('/')))
date_cols_map = {k: date_formatter(k) for k in date_cols}
reports_df = reports_df.rename(columns=date_cols_map)
date_cols = list(date_cols_map.values())
today = date_cols[-1]

# %% [markdown]
# [Return to top](#Introduction)
#
# ---
# # Filter data

# %%
# list US states and District of Columbia for later filtering/sorting
us_states = reports_df[(reports_df['iso3']=='USA')& \
            (reports_df['Admin2'].notna())]['Province_State'].unique()

# create df for US states data
states_df = reports_df[reports_df['Province_State'].isin(us_states)] \
            .set_index(['Report_Type','Province_State','Admin2'])[date_cols]

# %% [markdown]
# [Return to top](#Introduction)
#
# ---
# # Explore data

# %%
# plot an average line

report_type = 'cases'
state = 'Michigan'
days = 14
week_dates = date_cols[(-days-1):-1]
trend_df = states_df.query(f'Report_Type=="{report_type}" & Province_State=="{state}"').groupby(level='Province_State').sum().diff(axis=1)[week_dates]
# trend_df = trend_df[week_dates].where(~(trend_df[week_dates]<0), other=np.nan)
trend_df = trend_df.transpose().reset_index().rename(columns={'index':'Date'})
print(trend_df)
x = trend_df.index
y = trend_df[state]

plt.bar(x,y)
plt.xticks(ticks=np.arange(0,len(week_dates),2),labels=week_dates[::2],rotation=45,ha='right')
# trend line plot code from https://widu.tumblr.com/post/43624347354/matplotlib-trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),'r')
# Out:
# Province_State      Date  Michigan
# 0               08/03/20     616.0
# 1               08/04/20     801.0
# 2               08/05/20     718.0
# 3               08/06/20     763.0
# 4               08/07/20     814.0
# 5               08/08/20     721.0
# 6               08/09/20     535.0
# 7               08/10/20     580.0
# 8               08/11/20     907.0
# 9               08/12/20     476.0
# 10              08/13/20    1167.0
# 11              08/14/20     868.0
# 12              08/15/20    1058.0
# 13              08/16/20     477.0

# %%
# total us cases/deaths
states_df.groupby(level='Report_Type')[today].sum().to_frame(name='US_Totals')
# Out:
#              US_Totals
# Report_Type
# cases          5375762
# deaths          169698

# %%
# change in us cases/deaths in previous 7 days
states_df.groupby(level='Report_Type').sum().diff(axis=1)[date_cols[-8:-1]].sum(axis=1).to_frame(name='US_Weekly_Change')
# Out:
#              US_Weekly_Change
# Report_Type
# cases                360511.0
# deaths                 6958.0

# %%
# most recent case/death count by state
report_type = 'deaths'
states_df.loc[report_type].groupby(level='Province_State')[date_cols[-1]] \
            .sum().sort_values(ascending=False).to_frame(name='Cumulative_Cases').head(20)
# Out:
#                 Cumulative_Cases
# Province_State
# New York                   32827
# New Jersey                 15903
# California                 11148
# Texas                      10078
# Florida                     9141
# Massachusetts               8804
# Illinois                    7932
# Pennsylvania                7434
# Michigan                    6566
# Georgia                     4573
# Connecticut                 4453
# Louisiana                   4430
# Arizona                     4423
# Ohio                        3784
# Maryland                    3631
# Indiana                     3113
# Virginia                    2370
# North Carolina              2313
# South Carolina              2204
# Mississippi                 2043

# %%
# new cases/deaths in the last 7 days
report_type = 'cases'
states_df.loc[report_type].groupby(level='Province_State').sum().diff(axis=1)[date_cols[-7:]].sum(axis=1) \
            .sort_values(ascending=False).to_frame(name='Weekly_Change').head(10)
# Out:
#                 Weekly_Change
# Province_State
# California            64127.0
# Texas                 52066.0
# Florida               40610.0
# Georgia               20434.0
# Illinois              12032.0
# Tennessee             10996.0
# Missouri               8813.0
# North Carolina         8606.0
# Ohio                   7439.0
# Alabama                7099.0

# %%
# cases in the last 7 days
states_df.loc['cases'].groupby('Province_State').sum()[[date_cols[-8],today]].diff(axis=1)[date_cols[-1]]#.sort_values(ascending=False).head()
# Out:
# Province_State
# Alabama                  7099.0
# Alaska                    548.0
# Arizona                  6614.0
# Arkansas                 3282.0
# California              64127.0
# Colorado                 2515.0
# Connecticut               577.0
# Delaware                  876.0
# District of Columbia      467.0
# Florida                 40610.0
# Georgia                 20434.0
# Hawaii                   1544.0
# Idaho                    2981.0
# Illinois                12032.0
# Indiana                  6087.0
# Iowa                     3528.0
# Kansas                   3223.0
# Kentucky                 3948.0
# Louisiana                6519.0
# Maine                     124.0
# Maryland                 4709.0
# Massachusetts            2553.0
# Michigan                 5533.0
# Minnesota                4254.0
# Mississippi              4963.0
# Missouri                 8813.0
# Montana                   798.0
# Nebraska                 1940.0
# Nevada                   5075.0
# New Hampshire             153.0
# New Jersey               2682.0
# New Mexico               1093.0
# New York                 4648.0
# North Carolina           8606.0
# North Dakota              991.0
# Ohio                     7439.0
# Oklahoma                 4776.0
# Oregon                   1990.0
# Pennsylvania             5758.0
# Rhode Island              597.0
# South Carolina           6062.0
# South Dakota              669.0
# Tennessee               10996.0
# Texas                   52066.0
# Utah                     2525.0
# Vermont                    56.0
# Virginia                 6601.0
# Washington               4389.0
# West Virginia             872.0
# Wisconsin                5187.0
# Wyoming                   236.0
# Name: 08/16/20, dtype: float64

# %%
states_df
# Out:
#                                        01/22/20  01/23/20  01/24/20  01/25/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga            0         0         0         0
#                            Baldwin            0         0         0         0
#                            Barbour            0         0         0         0
#                            Bibb               0         0         0         0
#                            Blount             0         0         0         0
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned         0         0         0         0
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        01/26/20  01/27/20  01/28/20  01/29/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga            0         0         0         0
#                            Baldwin            0         0         0         0
#                            Barbour            0         0         0         0
#                            Bibb               0         0         0         0
#                            Blount             0         0         0         0
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned         0         0         0         0
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        01/30/20  01/31/20  ...  08/08/20  \
# Report_Type Province_State Admin2                          ...
# cases       Alabama        Autauga            0         0  ...      1086
#                            Baldwin            0         0  ...      3502
#                            Barbour            0         0  ...       573
#                            Bibb               0         0  ...       426
#                            Blount             0         0  ...       788
# ...                                         ...       ...  ...       ...
# deaths      Wyoming        Teton              0         0  ...         0
#                            Uinta              0         0  ...         0
#                            Unassigned         0         0  ...        27
#                            Washakie           0         0  ...         0
#                            Weston             0         0  ...         0
#
#                                        08/09/20  08/10/20  08/11/20  08/12/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1169      1174      1162      1188
#                            Baldwin         3544      3651      3670      3710
#                            Barbour          575       576       579       581
#                            Bibb             438       442       444       453
#                            Blount           800       812       816       825
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned        27        27        28        28
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        08/13/20  08/14/20  08/15/20  08/16/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1196      1196      1206      1218
#                            Baldwin         3744      3791      3839      3877
#                            Barbour          586       590       598       604
#                            Bibb             457       465       469       469
#                            Blount           835       848       854       860
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned        29        29        29        29
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        08/17/20
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1219
#                            Baldwin         3888
#                            Barbour          605
#                            Bibb             474
#                            Blount           863
# ...                                         ...
# deaths      Wyoming        Teton              0
#                            Uinta              0
#                            Unassigned        29
#                            Washakie           0
#                            Weston             0
#
# [6508 rows x 209 columns]

# %%
# cases in the last 7 days
weekly_change_df = states_df.loc['cases'].groupby('Province_State').sum().diff(axis=1,periods=7)[today].to_frame(name='new_cases')
weekly_change_df['total_cases'] = states_df.groupby('Province_State').sum()[today]
weekly_change_df['pct_change'] = weekly_change_df['new_cases']/weekly_change_df['total_cases']

cm = sns.light_palette("red", as_cmap=True)
weekly_change_df.sort_values(by='pct_change', ascending=False)#.style.background_gradient(cmap=cm)
# Out:
#                       new_cases  total_cases  pct_change
# Province_State
# Hawaii                   1593.0         5390    0.295547
# Alaska                    552.0         4400    0.125455
# Montana                   742.0         5930    0.125126
# Missouri                 8615.0        71480    0.120523
# Kentucky                 4506.0        41129    0.109558
# North Dakota              897.0         8910    0.100673
# Kansas                   3406.0        35285    0.096528
# West Virginia             859.0         8900    0.096517
# Idaho                    2723.0        28603    0.095200
# Oklahoma                 4584.0        49991    0.091697
# California              59194.0       649644    0.091118
# Texas                   51112.0       579490    0.088202
# Wyoming                   287.0         3390    0.084661
# Nevada                   5119.0        63741    0.080309
# Tennessee               10855.0       137194    0.079122
# Oregon                   1902.0        24073    0.079010
# Georgia                 19089.0       246471    0.077449
# Indiana                  5985.0        85012    0.070402
# South Dakota              728.0        10595    0.068712
# Iowa                     3680.0        54203    0.067893
# Wisconsin                4411.0        67235    0.065606
# Mississippi              4914.0        75334    0.065230
# Florida                 37140.0       589690    0.062982
# Minnesota                4253.0        67859    0.062674
# Ohio                     7084.0       113776    0.062263
# Virginia                 6537.0       110678    0.059063
# Washington               4112.0        70071    0.058683
# Alabama                  6510.0       112297    0.057971
# Illinois                12676.0       218918    0.057903
# Nebraska                 1795.0        31194    0.057543
# Arkansas                 3076.0        54106    0.056851
# North Carolina           8036.0       149175    0.053870
# Delaware                  894.0        17186    0.052019
# Utah                     2405.0        47526    0.050604
# South Carolina           5542.0       110015    0.050375
# Michigan                 5189.0       110010    0.047168
# Maryland                 4392.0       104885    0.041874
# Louisiana                6000.0       143679    0.041760
# Colorado                 2190.0        55511    0.039452
# New Mexico                936.0        24302    0.038515
# Pennsylvania             5231.0       137721    0.037983
# Maine                     161.0         4340    0.037097
# Vermont                    58.0         1588    0.036524
# Arizona                  6183.0       199449    0.031000
# District of Columbia      429.0        13924    0.030810
# Rhode Island              639.0        21716    0.029425
# New Hampshire             156.0         7441    0.020965
# Massachusetts            2356.0       132911    0.017726
# New Jersey               2623.0       204023    0.012856
# Connecticut               571.0        55711    0.010249
# New York                 4568.0       459428    0.009943

# %%
states_df
# Out:
#                                        01/22/20  01/23/20  01/24/20  01/25/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga            0         0         0         0
#                            Baldwin            0         0         0         0
#                            Barbour            0         0         0         0
#                            Bibb               0         0         0         0
#                            Blount             0         0         0         0
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned         0         0         0         0
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        01/26/20  01/27/20  01/28/20  01/29/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga            0         0         0         0
#                            Baldwin            0         0         0         0
#                            Barbour            0         0         0         0
#                            Bibb               0         0         0         0
#                            Blount             0         0         0         0
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned         0         0         0         0
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        01/30/20  01/31/20  ...  08/09/20  \
# Report_Type Province_State Admin2                          ...
# cases       Alabama        Autauga            0         0  ...      1169
#                            Baldwin            0         0  ...      3544
#                            Barbour            0         0  ...       575
#                            Bibb               0         0  ...       438
#                            Blount             0         0  ...       800
# ...                                         ...       ...  ...       ...
# deaths      Wyoming        Teton              0         0  ...         0
#                            Uinta              0         0  ...         0
#                            Unassigned         0         0  ...        27
#                            Washakie           0         0  ...         0
#                            Weston             0         0  ...         0
#
#                                        08/10/20  08/11/20  08/12/20  08/13/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1174      1162      1188      1196
#                            Baldwin         3651      3670      3710      3744
#                            Barbour          576       579       581       586
#                            Bibb             442       444       453       457
#                            Blount           812       816       825       835
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned        27        28        28        29
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        08/14/20  08/15/20  08/16/20  08/17/20  \
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1196      1206      1218      1219
#                            Baldwin         3791      3839      3877      3888
#                            Barbour          590       598       604       605
#                            Bibb             465       469       469       474
#                            Blount           848       854       860       863
# ...                                         ...       ...       ...       ...
# deaths      Wyoming        Teton              0         0         0         0
#                            Uinta              0         0         0         0
#                            Unassigned        29        29        29        29
#                            Washakie           0         0         0         0
#                            Weston             0         0         0         0
#
#                                        08/18/20
# Report_Type Province_State Admin2
# cases       Alabama        Autauga         1235
#                            Baldwin         3906
#                            Barbour          606
#                            Bibb             476
#                            Blount           887
# ...                                         ...
# deaths      Wyoming        Teton              0
#                            Uinta              0
#                            Unassigned        29
#                            Washakie           0
#                            Weston             0
#
# [6508 rows x 210 columns]

# %%
# calculate totals, change, and percent change based on weekly interval
interval= 7
start = ((len(date_cols) - 1) % interval)
weekly_change_df = states_df.loc['cases'].groupby('Province_State').sum().diff(axis=1,periods=7)[date_cols[start::interval]] # weekly change ending on date
weekly_totals_df = states_df.loc['cases'].groupby('Province_State').sum()[date_cols[start::interval]] # case totals ending on date
weekly_change_pct_df = (weekly_change_df/weekly_totals_df)*100 # percent of weekly change over total cases

# cm = sns.light_palette("red", as_cmap=True)
# weekly_change_pct_df[weekly_change_pct_df.columns[-10:]].style.background_gradient(cmap=cm).highlight_null('white') # change in weekly percentage from week to week

cm = sns.diverging_palette(120,10, as_cmap=True)
weekly_change_pct_df.diff(axis=1)[weekly_change_pct_df.columns[-8:]].style.background_gradient(cmap=cm).highlight_null('white') # change in weekly percentage from week to week
# Out:
# <style  type="text/css" >
# #T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow31_col3{
#             background-color:  #f4c6c9;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow7_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow17_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow43_col5{
#             background-color:  #b0c9a5;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col2{
#             background-color:  #e5747c;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow38_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow42_col3{
#             background-color:  #eff6ec;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow26_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow28_col1{
#             background-color:  #a4c197;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col6,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow5_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow41_col3{
#             background-color:  #f2babe;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow0_col7{
#             background-color:  #60904c;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow14_col3{
#             background-color:  #e98c93;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow6_col2{
#             background-color:  #f8d8db;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col2{
#             background-color:  #db434e;
#             color:  #f1f1f1;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow9_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow27_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow47_col4{
#             background-color:  #c2d6b9;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow11_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow30_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow33_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow43_col6{
#             background-color:  #f2bcc0;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col5{
#             background-color:  #6f9a5c;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col6,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow12_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow36_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow48_col3{
#             background-color:  #4f8438;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow1_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow25_col3{
#             background-color:  #e36b74;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow36_col3{
#             background-color:  #a5c199;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow12_col5{
#             background-color:  #89ae7a;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow36_col0{
#             background-color:  #a6c29a;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col6,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow8_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow12_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow14_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow20_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow20_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow21_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow23_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow31_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow31_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow31_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow32_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow34_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow35_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow38_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow41_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow43_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow46_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow47_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow50_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow50_col2{
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow2_col7,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow7_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow24_col6{
#             background-color:  #eaf3e6;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow35_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow47_col5{
#             background-color:  #b1caa6;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow17_col2,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow20_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow45_col7{
#             background-color:  #e8878e;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow10_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow50_col5{
#             background-color:  #95b687;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow3_col6,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow46_col2{
#             background-color:  #ec999f;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow15_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow18_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow22_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow32_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow33_col7{
#             background-color:  #cddec5;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col1,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow49_col0{
#             background-color:  #fae7e8;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col2{
#             background-color:  #fbe8ea;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col3,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow20_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow30_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow37_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow39_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow46_col0{
#             background-color:  #c3d7bb;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col4,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow27_col5,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow29_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow32_col0,#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow37_col4{
#             background-color:  #c6d9be;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col6{
#             background-color:  #ed9da3;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea_90fa_a45e60cb13cdrow4_col7{
#             background-color:  #f0b1b5;
#             color:  #000000;
#         }#T_eb1af388_e286_11ea

# %%
def plot_county_heatmaps(state,report_type='cases'):
    test_df = states_df.loc[(report_type,state)][date_cols].sort_values(by=[date_cols[-1]],ascending=False).diff(axis=1).fillna(0).head(5)
    test_df = test_df[date_cols].where(~(test_df[date_cols]<0), other=np.nan)
    counties = test_df.index.to_list()
    fig, ax = plt.subplots(len(counties)+1,1,figsize=(12, len(counties)/1.5))
    for i,county in enumerate(counties):
        nbins = 4
        bin_labels = [i for i in range(nbins)]
        plot = pd.cut(test_df.loc[county],bins=nbins,labels=bin_labels).astype('float').to_frame(name='cases').transpose()
        sns.heatmap(plot,cmap='Reds',cbar=False,yticklabels=[county],xticklabels=False,ax=ax[i])
        plt.setp(ax[i].yaxis.get_majorticklabels(), rotation=0)
    sns.heatmap(pd.DataFrame([1,2,3,4]).transpose(),cmap='Reds',cbar=False,ax=ax[-1],yticklabels=False, xticklabels=['Less','','','More'])
    ax[0].title.set_text(f'Daily Reported Cases in {state} - Top 5 Counties with Highest Total Cases\n') 
    plt.show()
    
plot_county_heatmaps('Florida')

# %%
def plot_state_heatmaps(report_type='cases',n_states=10):
    daily_cases_df = states_df.loc[report_type].groupby('Province_State').sum()[date_cols]
    daily_cases_df = daily_cases_df.sort_values(by=[date_cols[-1]],ascending=False).diff(axis=1).head(n_states)
    daily_cases_df = daily_cases_df[date_cols].where(~(daily_cases_df[date_cols]<0), other=np.nan)
    states = daily_cases_df.index.to_list()
    fig, ax = plt.subplots(len(states)+1,1,figsize=(12, len(states)/2))
    for i,state in enumerate(states):
        nbins = 5
        bin_labels = [i for i in range(nbins)]
        plot = pd.cut(daily_cases_df.loc[state],bins=nbins,labels=bin_labels).astype('float').to_frame().transpose()
        sns.heatmap(plot,cmap='Reds',vmin=-.5,cbar=False,yticklabels=[state],xticklabels=False,ax=ax[i])
        plt.setp(ax[i].yaxis.get_majorticklabels(), rotation=0)
    cbar = pd.DataFrame(range(nbins)).transpose()
    sns.heatmap(cbar,cmap='Reds',vmin=-.5,cbar=False,ax=ax[-1],yticklabels=False, xticklabels=['Fewer','','','','More'])
    ax[0].title.set_text(f'Daily Reported COVID-19 {report_type}'
                         f' - Top {n_states} States with Highest Total {report_type}'
                         f' - {date_cols[0]} through {date_cols[-1]}\n') 
    plt.show()

print()
print()
print()
    
plot_state_heatmaps(n_states=20)

print()

# %% [markdown]
# ## Functions for data exploration and plotting

# %%
# get cumulateive case and death counts

def cumulative_case_and_death_counts(state=False,county=False,date=date_cols[-1]):
    """Returns the total case and death counts for
    a given county and state as of a given date.
    If no state or county is passed, the US totals will be used
    If a date is not passed, the most recent date will be used."""
    
    if county:
        counts = states_df.query(f'Province_State=="{state}" & Admin2=="{county}"')[date]
    elif state:
        counts = states_df.query(f'Province_State=="{state}"').groupby(['Report_Type','Province_State']).sum()[date]
    else:
        counts = states_df.groupby('Report_Type').sum()[date].to_frame()
    
    res = f"""There have been {counts.loc['cases'][0]} cases of COVID-19 and """ \
            f"""{counts.loc['deaths'][0]} deaths reported in {f'{county} County, ' if county else ''}""" \
            f"""{state if state else 'the United States'} as of {date}."""
    
    return res

# %%
# get first reported case date and return dates for plotting
def get_plot_dates(state=False):
    first_reported_grouping = ('cases',state) if state else ('cases')
    first_reported_case = states_df.loc[first_reported_grouping].sum().ne(0).idxmax()
    plot_dates = date_cols[date_cols.index(first_reported_case)-1:] if state else date_cols
    return plot_dates

# fix error for US data

# %%
# plot daily change in cases/deaths for a given state or county

def plot_daily_change(state=False,county=False,report_type='cases',time_frame='all'):
    """Plots the daily change in cases/deaths for a given state or county.
If no state or county is passed, the total US count will be used.

Accepted `report_type` values are:
 - 'cases': case data
 - 'deaths': death data
    
"""
    plot_dates = get_plot_dates(state)
    
    if county:
        plot_df = states_df.loc[(report_type,state,county)].diff()[plot_dates]
    elif state:
        plot_df = states_df.loc[(report_type,state)].sum().diff()[plot_dates]
    else:
        plot_df = states_df.loc[report_type].sum().diff()[plot_dates]

    plt.figure(figsize=(12, 5))
    
    color = 'tab:red' if report_type=='cases' else 'tab:gray'
    
    daily_cases = plot_df.plot(kind='bar',color=color,alpha=.4)
    
    average_cases = plot_df.rolling(7,center=True).mean()
    average_cases.plot(linewidth=2,color=color)
    
    plt.xticks(ticks=np.arange(0,len(plot_dates), 15),labels=plot_dates[::15], \
                rotation=45,ha='right')
    
    plt.title(f"""Seven-day rolling average of daily COVID-19 {report_type} for """ \
              f"""{f'{county} County, ' if county else ''}""" \
              f"""{state if state else 'the United States'} as of {date_cols[-1]}""")
    
    plt.ylabel(f'Number of {report_type}')
    plt.xlabel('Date')
    plt.legend().remove()
    
    for i in list(plt.yticks()[0][::2]):
        plt.axhline(y=i,linewidth=1.25, color='lightgray',alpha=.75, \
                    linestyle='dashed',zorder=-5)
   
    plt.fill_between(plot_dates,average_cases,color=color,alpha=.15)
    plt.show()

# %%
# view a report of cases/deaths with charts for a given state or county

def status_report(state=False,county=False):
    
    print(f"\n{cumulative_case_and_death_counts(state,county)}\n")
    
    for report_type in ['cases','deaths']:
        plot_daily_change(state,county,report_type=report_type)

# %% [markdown]
# [Return to top](#Introduction)
#
# ---
# # Visualize data

# %%
# view report for United States

status_report()
# Out:
# There have been 5375762 cases of COVID-19 and 169698 deaths reported in the United States as of 08/16/20.

# %%
# view report for Massachusetts

status_report(state='Massachusetts')
# Out:
# There have been 123593 cases of COVID-19 and 8838 deaths reported in Massachusetts as of 08/16/20.

# %%
# view report for New York City, New York

status_report(state="Michigan", county="Oakland")
# Out:
# There have been 16469 cases of COVID-19 and 1141 deaths reported in Oakland County, Michigan as of 08/16/20.
